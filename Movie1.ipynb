# %%
import pandas as pd
import numpy as np

df = pd.read_csv("movie_metadata.csv")

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df = df.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title', 'language']]

# %%
df['language'] = df['language'].replace(np.nan, 'unknown')
df['actor_1_name'] = df['actor_1_name'].replace(np.nan, 'unknown')
df['actor_2_name'] = df['actor_2_name'].replace(np.nan, 'unknown')
df['actor_3_name'] = df['actor_3_name'].replace(np.nan, 'unknown')
df['director_name'] = df['director_name'].replace(np.nan, 'unknown')

# %%
df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# language         0
# dtype: int64

# %%
df['genres'] = df['genres'].str.replace('|', ' ')

# %%
df.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title language
# 0                                            Avatar   English
# 1          Pirates of the Caribbean: At World's End   English
# 2                                           Spectre   English
# ...

# %%
df['movie_title'] = df['movie_title'].str.lower()

# %%
df['movie_title'][0]
# Out:
# 'avatar\xa0'

# %%
df['movie_title'] = df['movie_title'].apply(lambda x : x[:-1])
df['movie_title'][0]
# Out:
# 'avatar'

# %%
df.to_csv("gbc1.csv")

# %% [markdown]
# ## Working on Credits Dataset

# %%
df1 = pd.read_csv("movies_metadata.csv")
df2 = pd.read_csv("credits.csv")
df2.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
df1.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df1['year'] = pd.to_datetime(df1['release_date'], errors='coerce' )

# %%
df1['year'] = df1['year'].dt.year

# %%
df1['year'].value_counts().sort_index()
# Out:
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: year, Length: 135, dtype: int64

# %%
new_df = df1.loc[df1.year == 2017,['genres','id','title','year']]

# %%
new_df
# Out:
#                                                   genres      id  \
# 26560  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  166426
# 26561  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  141052
# 26565  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  284053
# 26566  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  283995
# 30536  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...  245842
# ...                                                  ...     ...
# 45398  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  468707
# 45417  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...  461297
# 45437  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...  455661
# 45453  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...  404604
# 45465                                                 []  461257
#
#                                                   title    year
# 26560  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# ...

# %%
new_df['id'] = new_df['id'].astype(int)

# %%
new_df.dtypes
# Out:
# genres     object
# id          int64
# title      object
# year      float64
# dtype: object

# %%
data = pd.merge(new_df, df2, on='id')

# %%
data.head()
# Out:
#                                               genres      id  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  166426
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  141052
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  284053
# 3  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  283995
# 4  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...  245842
#
#                                               title    year  \
# 0  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# 1                                    Justice League  2017.0
# 2                                    Thor: Ragnarok  2017.0
# 3                    Guardians of the Galaxy Vol. 2  2017.0
# 4                               The King's Daughter  2017.0
#
#                                                 cast  \
# 0  [{'cast_id': 1, 'character': 'Captain Jack Spa...
# 1  [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 2  [{'cast_id': 0, 'character': 'Thor Odinson', '...
# ...

# %%
import ast
data['genres'] = data['genres'].map(lambda x: ast.literal_eval(x))
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))

# %%
def make_genresList(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name') == 'Science Fiction':
            scifi = 'Sci-Fi'
            gen.append(scifi)
        else:
            gen.append(i.get('name'))
    if gen == []:
        return np.NaN
    else:
        return (st.join(gen))

# %%
data['genres_list'] = data['genres'].map(lambda x: make_genresList(x))

# %%
data['genres_list']
# Out:
# 0      Adventure Action Fantasy Comedy
# 1      Action Adventure Fantasy Sci-Fi
# 2      Action Adventure Fantasy Sci-Fi
# 3       Action Adventure Comedy Sci-Fi
# 4             Fantasy Action Adventure
#                     ...
# 526                     Romance Comedy
# 527         Crime Comedy Action Family
# 528    Family Animation Romance Comedy
# 529               Crime Drama Thriller
# 530                                NaN
# Name: genres_list, Length: 531, dtype: object

# %%
def get_actor1(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == []:
        return np.NaN
    else:
        return (casts[0])

# %%
data['actor_1_name'] = data['cast'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=1:
        return np.NaN
    else:
        return (casts[1])

# %%
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=2:
        return np.NaN
    else:
        return (casts[2])

# %%
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))

# %%
def get_directors(x):
    dt = []
    st = " "
    for i in x:
        if i.get('job') == 'Director':
            dt.append(i.get('name'))
    if dt == []:
        return np.NaN
    else:
        return (st.join(dt))

# %%
data['director_name'] = data['crew'].map(lambda x: get_directors(x))

# %%
movie = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','title']]

# %%
movie
# Out:
#                       director_name          actor_1_name    actor_2_name  \
# 0    Joachim Rønning Espen Sandberg           Johnny Depp   Javier Bardem
# 1                       Zack Snyder           Ben Affleck    Henry Cavill
# 2                     Taika Waititi       Chris Hemsworth  Tom Hiddleston
# 3                        James Gunn           Chris Pratt     Zoe Saldana
# 4                     Sean McNamara        Pierce Brosnan    William Hurt
# ..                              ...                   ...             ...
# 526                Hannaleena Hauru        Inka Haapamäki   Rosa Honkonen
# 527           Jonathan A. Rosenbaum  Lou Diamond Phillips   Wallace Shawn
# 528        Beth David Esteban Bravo                   NaN             NaN
# 529                    Ravi Udyawar        Sridevi Kapoor       Sajal Ali
# 530                   Daisy Asquith                   NaN             NaN
#
#         actor_3_name                      genres_list  \
# ...

# %%
movie = movie.dropna(how='any')

# %%
movie.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres_list      0
# title            0
# dtype: int64

# %%
movie = movie.rename(columns={'genres_list':'genres'})
movie = movie.rename(columns={'title':'movie_title'})
movie['movie_title'] = movie['movie_title'].str.lower()

# %%
movie['comb'] = movie['actor_1_name'] + ' ' + movie['actor_2_name'] + ' '+ movie['actor_3_name'] + ' '+ movie['director_name'] +' ' + movie['genres']

# %%
old = pd.read_csv('gbc1.csv')

# %%
old['comb'] = old['actor_1_name'] + ' ' + old['actor_2_name'] + ' '+ old['actor_3_name'] + ' '+ old['director_name'] +' ' + old['genres']

# %%
new = old.append(movie)

# %%
new.shape
# Out:
# (5501, 9)

# %%
new.drop_duplicates(subset ="movie_title", keep = 'last', inplace = True)

# %%
new.to_csv('new_data.csv',index=False)

# %%
df = pd.read_csv('new_data.csv')
df
# Out:
#       Unnamed: 0          director_name          actor_1_name  \
# 0            0.0          James Cameron           CCH Pounder
# 1            1.0         Gore Verbinski           Johnny Depp
# 2            2.0             Sam Mendes       Christoph Waltz
# 3            3.0      Christopher Nolan             Tom Hardy
# 4            4.0            Doug Walker           Doug Walker
# ...          ...                    ...                   ...
# 5359         NaN            Jim Strouse      Jessica Williams
# 5360         NaN            Farhad Mann         Adelaide Kane
# 5361         NaN       Hannaleena Hauru        Inka Haapamäki
# 5362         NaN  Jonathan A. Rosenbaum  Lou Diamond Phillips
# 5363         NaN           Ravi Udyawar        Sridevi Kapoor
#
#                 actor_2_name          actor_3_name  \
# 0           Joel David Moore             Wes Studi
# 1              Orlando Bloom        Jack Davenport
# 2               Rory Kinnear      Stephanie Sigman
# ...

# %% [markdown]
# ### Extracting features of 2018 movies from Wikipedia

# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 264  DECEMBER         25             Holmes & Watson
# 265  DECEMBER         25                        Vice
# 266  DECEMBER         25         On the Basis of Sex
# 267  DECEMBER         25                   Destroyer
# 268  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
from omdbapi.movie_search import GetMovie
import json
import requests

# %%
genres = []
for i in range(268):
    movie = GetMovie(title=df['Title'][i], api_key='e3fc1d3f', plot='full')
    data = movie.get_data('Genre')
    genres.append(data)

# %%
from pandas import DataFrame
df3 = DataFrame(genres,columns=['Genre'])

# %%
df['genres'] = df3

# %%
df_en = df[['Title','Cast and crew','genres']]

# %%
df_en
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 264             Holmes & Watson
# 265                        Vice
# 266         On the Basis of Sex
# 267                   Destroyer
# 268  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 264  Etan Cohen (director/screenplay); Will Ferrell...
# 265  Adam McKay (director/screenplay); Christian Ba...
# 266  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_en['director_name'] = df_en['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-61-acbd25dcf5d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_en['director_name'] = df_en['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_en['actor_1_name'] = df_en['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-63-9b2cd0307416>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_en['actor_1_name'] = df_en['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_en['actor_2_name'] = df_en['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-65-1978d7b65e8a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_en['actor_2_name'] = df_en['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_en['actor_3_name'] = df_en['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_en = df_en.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_en.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 264          Etan Cohen     Will Ferrell          John C. Reilly
# 265          Adam McKay   Christian Bale               Amy Adams
# 266          Mimi Leder   Felicity Jones            Armie Hammer
# 267        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 268         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                             genres  \
# 0    Leigh Whannell                          Horror, Mystery, Thriller
# ...

# %%
link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df_b = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df_b
# Out:
#     Opening  Opening.1             Title         Director  \
# 0       JAN         12              1921     Vikram Bhatt
# 1       JAN         12       Kaalakaandi     Akshat Verma
# 2       JAN         12         Mukkabaaz   Anurag Kashyap
# 3       JAN         15        Phir Se...      Kunal Kohli
# 4       JAN         19  My Birthday Song       Samir Soni
# ..      ...        ...               ...              ...
# 99      NOV         30      Rajma Chawal      Leena Yadav
# 100     DEC          7         Kedarnath  Abhishek Kapoor
# 101     DEC         14   Ascharyachakit!     Samit Kakkad
# 102     DEC         21              Zero    Aanand L. Rai
# 103     DEC         28            Simmba     Rohit Shetty
#
#                                                   Cast  \
# 0    Zareen KhanKaran KundraTobby HinstonSonia Arms...
# 1    Saif Ali KhanIsha TalwarShenaz TreasuryAkshay ...
# 2    Vineet Kumar SinghZoya HussainRavi KishanJimmy...
# ...

# %%
from omdbapi.movie_search import GetMovie
import json
import requests

# %%
genres = []
for i in range(104):
    movie = GetMovie(title=df_b['Title'][i], api_key='e3fc1d3f', plot='full')
    data = movie.get_data('Genre')
    genres.append(data)

# %%
from pandas import DataFrame
df4 = DataFrame(genres,columns=['Genre'])

# %%
df_b['genres'] = df4

# %%
df_b['Cast and crew'] = df_b['Cast']

# %%
df_en = df_b[['Title','Director','Cast and crew','genres']]

# %%
df_en
# Out:
#                 Title         Director  \
# 0                1921     Vikram Bhatt
# 1         Kaalakaandi     Akshat Verma
# 2           Mukkabaaz   Anurag Kashyap
# 3          Phir Se...      Kunal Kohli
# 4    My Birthday Song       Samir Soni
# ..                ...              ...
# 99       Rajma Chawal      Leena Yadav
# 100         Kedarnath  Abhishek Kapoor
# 101   Ascharyachakit!     Samit Kakkad
# 102              Zero    Aanand L. Rai
# 103            Simmba     Rohit Shetty
#
#                                          Cast and crew  \
# 0    Zareen KhanKaran KundraTobby HinstonSonia Arms...
# 1    Saif Ali KhanIsha TalwarShenaz TreasuryAkshay ...
# 2    Vineet Kumar SinghZoya HussainRavi KishanJimmy...
# 3                Jennifer WingetKunal KohliRajit Kapur
# 4                       Sanjay SuriNora FatehiPitobash
# ..                                                 ...
# 99              Rishi KapoorAnirudh TanwarAmyra Dastur
# ...

# %%
df_en['Cast and crew'] = df_en['Cast and crew'].str.replace( r"([A-Z])", r" \1").str.strip()
# Out:
# <ipython-input-83-add6444aa4b9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_en['Cast and crew'] = df_en['Cast and crew'].str.replace( r"([A-Z])", r" \1").str.strip()

# %%
df_en
# Out:
#                 Title         Director  \
# 0                1921     Vikram Bhatt
# 1         Kaalakaandi     Akshat Verma
# 2           Mukkabaaz   Anurag Kashyap
# 3          Phir Se...      Kunal Kohli
# 4    My Birthday Song       Samir Soni
# ..                ...              ...
# 99       Rajma Chawal      Leena Yadav
# 100         Kedarnath  Abhishek Kapoor
# 101   Ascharyachakit!     Samit Kakkad
# 102              Zero    Aanand L. Rai
# 103            Simmba     Rohit Shetty
#
#                                          Cast and crew  \
# 0    Zareen  Khan Karan  Kundra Tobby  Hinston Soni...
# 1    Saif  Ali  Khan Isha  Talwar Shenaz  Treasury ...
# 2    Vineet  Kumar  Singh Zoya  Hussain Ravi  Kisha...
# 3           Jennifer  Winget Kunal  Kohli Rajit  Kapur
# 4                   Sanjay  Suri Nora  Fatehi Pitobash
# ..                                                 ...
# 99         Rishi  Kapoor Anirudh  Tanwar Amyra  Dastur
# ...

# %%
df_en.to_csv("2018_Movies.csv")

# %%
df10 = pd.read_csv("2018_Movies_cleaned.csv")
df10.head()
# Out:
#    Unnamed: 0       movie_title   director_name  \
# 0           0              1921    Vikram Bhatt
# 1           1       Kaalakaandi    Akshat Verma
# 2           2         Mukkabaaz  Anurag Kashyap
# 3           3        Phir Se...     Kunal Kohli
# 4           4  My Birthday Song      Samir Soni
#
#                                        Cast and crew  \
# 0  Zareen  Khan Karan  Kundra Tobby  Hinston Soni...
# 1   Shenaz  Treasury Akshay  Oberoi Vijay  Raaz D...
# 2  Vineet  Kumar  Singh Zoya  Hussain Ravi  Kisha...
# 3         Jennifer  Winget Kunal  Kohli Rajit  Kapur
# 4                 Sanjay  Suri Nora  Fatehi Pitobash
#
#                      genres          actor_1_name   actor_2_name  \
# 0  Horror, Mystery, Romance          Zareen  Khan  Karan  Kundra
# 1          Comedy, Thriller       Saif  Ali  Khan   Isha  Talwar
# 2            Romance, Drama  Vineet  Kumar  Singh  Zoya  Hussain
# 3                   Romance      Jennifer  Winget   Kunal  Kohli
# ...

# %%
hnew_df18 = df10.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
hnew_df18
# Out:
#        director_name            actor_1_name         actor_2_name  \
# 0       Vikram Bhatt            Zareen  Khan        Karan  Kundra
# 1       Akshat Verma         Saif  Ali  Khan         Isha  Talwar
# 2     Anurag Kashyap    Vineet  Kumar  Singh        Zoya  Hussain
# 3        Kunal Kohli        Jennifer  Winget         Kunal  Kohli
# 4         Samir Soni            Sanjay  Suri         Nora  Fatehi
# ..               ...                     ...                  ...
# 98       Leena Yadav           Rishi  Kapoor      Anirudh  Tanwar
# 99   Abhishek Kapoor  Sushant  Singh  Rajput      Sara  Ali  Khan
# 100     Samit Kakkad          Priyanka  Bose  Vaibhav  Raj  Gupta
# 101    Aanand L. Rai        Shah  Rukh  Khan        Katrina  Kaif
# 102     Rohit Shetty           Ranveer Singh      Sara  Ali  Khan
#
#          actor_3_name                    genres       movie_title
# 0      Tobby  Hinston  Horror, Mystery, Romance              1921
# ...

# %%
hnew_df18['actor_2_name'] = hnew_df18['actor_2_name'].replace(np.nan, 'unknown')
hnew_df18['actor_3_name'] = hnew_df18['actor_3_name'].replace(np.nan, 'unknown')
hnew_df18['movie_title'] = hnew_df18['movie_title'].str.lower()

# %%
hnew_df18['comb'] = hnew_df18['actor_1_name'] + ' ' + hnew_df18['actor_2_name'] + ' '+ hnew_df18['actor_3_name'] + ' '+ hnew_df18['director_name'] +' ' + hnew_df18['genres']

# %%
hnew_df18
# Out:
#        director_name            actor_1_name         actor_2_name  \
# 0       Vikram Bhatt            Zareen  Khan        Karan  Kundra
# 1       Akshat Verma         Saif  Ali  Khan         Isha  Talwar
# 2     Anurag Kashyap    Vineet  Kumar  Singh        Zoya  Hussain
# 3        Kunal Kohli        Jennifer  Winget         Kunal  Kohli
# 4         Samir Soni            Sanjay  Suri         Nora  Fatehi
# ..               ...                     ...                  ...
# 98       Leena Yadav           Rishi  Kapoor      Anirudh  Tanwar
# 99   Abhishek Kapoor  Sushant  Singh  Rajput      Sara  Ali  Khan
# 100     Samit Kakkad          Priyanka  Bose  Vaibhav  Raj  Gupta
# 101    Aanand L. Rai        Shah  Rukh  Khan        Katrina  Kaif
# 102     Rohit Shetty           Ranveer Singh      Sara  Ali  Khan
#
#          actor_3_name                    genres       movie_title  \
# 0      Tobby  Hinston  Horror, Mystery, Romance              1921
# ...

# %%
df_2018 = new_df18.append(hnew_df18,ignore_index=True)

# %%
df_2018
# Out:
#           director_name            actor_1_name            actor_2_name  \
# 0          Adam Robitel               Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein           Alex Pettyfer  James Freedson-Jackson
# 2            Simon West          Dominic Cooper          Austin Stowell
# 3      Warwick Thornton             Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra             Liam Neeson            Vera Farmiga
# ..                  ...                     ...                     ...
# 367         Leena Yadav           Rishi  Kapoor         Anirudh  Tanwar
# 368     Abhishek Kapoor  Sushant  Singh  Rajput         Sara  Ali  Khan
# 369        Samit Kakkad          Priyanka  Bose     Vaibhav  Raj  Gupta
# 370       Aanand L. Rai        Shah  Rukh  Khan           Katrina  Kaif
# 371        Rohit Shetty           Ranveer Singh         Sara  Ali  Khan
#
#         actor_3_name                                             genres  \
# ...

# %%
df_2018.to_csv("2018_Films_All.csv")
